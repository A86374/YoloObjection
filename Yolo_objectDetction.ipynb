# %%
# Import necessary packages
import numpy as np
import time
import cv2
import os

# Mount Google Drive (if using Google Colab)
from google.colab import drive
drive.mount('/content/drive')

# Define paths
input_video_path = "/content/drive/My Drive/overpass.mp4"
output_video_path = "/content/drive/My Drive/output/overpass_output.avi"
yolo_folder_path = "/content/drive/My Drive/yolo-coco"

# Create output folder if it doesn’t exist
if not os.path.exists("/content/drive/My Drive/output"):
    os.makedirs("/content/drive/My Drive/output")

# Create YOLO folder and download files if they don’t exist
if not os.path.exists(yolo_folder_path):
    os.makedirs(yolo_folder_path)

    # Download YOLO files if not found in yolo-coco directory
    # !wget -O "{yolo_folder_path}/yolov3.cfg" https://raw.githubusercontent.com/pjreddie/darknet/master/cfg/yolov3.cfg
    # !wget -O "{yolo_folder_path}/yolov3.weights" https://pjreddie.com/media/files/yolov3.weights
    # !wget -O "{yolo_folder_path}/coco.names" https://raw.githubusercontent.com/pjreddie/darknet/master/data/coco.names

# Set paths to YOLO files
args = {
    "input": input_video_path,
    "output": output_video_path,
    "yolo": yolo_folder_path,
    "confidence": 0.5,
    "threshold": 0.3
}

# Load the COCO class labels YOLO was trained on
labelsPath = os.path.sep.join([args["yolo"], "coco.names"])
LABELS = open(labelsPath).read().strip().split("\n")

# Initialize colors for each class label
np.random.seed(42)
COLORS = np.random.randint(0, 255, size=(len(LABELS), 3), dtype="uint8")

# Paths to YOLO weights and config
weightsPath = os.path.sep.join([args["yolo"], "yolov3.weights"])
configPath = os.path.sep.join([args["yolo"], "yolov3.cfg"])

# Load YOLO object detector
print("[INFO] Loading YOLO from disk...")
net = cv2.dnn.readNetFromDarknet(configPath, weightsPath)
ln = net.getLayerNames()
try:
    ln = [ln[i[0] - 1] for i in net.getUnconnectedOutLayers()]
except IndexError:
    ln = [ln[i - 1] for i in net.getUnconnectedOutLayers()]

# Initialize video stream
vs = cv2.VideoCapture(args["input"])

# Check if the video was opened successfully
if not vs.isOpened():
    print("[ERROR] Could not open video file.")
else:
    print("[INFO] Video file opened successfully.")

# Try reading the first frame to confirm successful capture
(grabbed, frame) = vs.read()
if grabbed:
    print("[INFO] First frame read successfully.")
    print(f"[INFO] Frame dimensions: {frame.shape[1]}x{frame.shape[0]}")
else:
    print("[ERROR] Could not read the first frame. Check the video file.")

# Proceed only if the video was successfully opened and the first frame was read
if not grabbed:
    vs.release()
    raise Exception("Failed to capture video. Ensure the video path is correct and accessible.")

writer = None
(W, H) = (None, None)
frame_count = 0

# Try to determine the total number of frames
try:
    total = int(vs.get(cv2.CAP_PROP_FRAME_COUNT))
    print(f"[INFO] {total} total frames in video")
except:
    print("[INFO] Could not determine # of frames in video")
    total = -1

# Loop over frames from video
while True:
    (grabbed, frame) = vs.read()
    if not grabbed:
        break

    frame_count += 1
    print(f"[INFO] Processing frame {frame_count}")

    if W is None or H is None:
        (H, W) = frame.shape[:2]

    # YOLO forward pass
    blob = cv2.dnn.blobFromImage(frame, 1 / 255.0, (416, 416), swapRB=True, crop=False)
    net.setInput(blob)
    layerOutputs = net.forward(ln)

    boxes = []
    confidences = []
    classIDs = []

    # Process detections
    for output in layerOutputs:
        for detection in output:
            scores = detection[5:]
            classID = np.argmax(scores)
            confidence = scores[classID]

            if confidence > args["confidence"]:
                box = detection[0:4] * np.array([W, H, W, H])
                (centerX, centerY, width, height) = box.astype("int")

                x = int(centerX - (width / 2))
                y = int(centerY - (height / 2))

                boxes.append([x, y, int(width), int(height)])
                confidences.append(float(confidence))
                classIDs.append(classID)

    idxs = cv2.dnn.NMSBoxes(boxes, confidences, args["confidence"], args["threshold"])

    if len(idxs) > 0:
        for i in idxs.flatten():
            (x, y) = (boxes[i][0], boxes[i][1])
            (w, h) = (boxes[i][2], boxes[i][3])

            color = [int(c) for c in COLORS[classIDs[i]]]
            cv2.rectangle(frame, (x, y), (x + w, y + h), color, 2)
            text = f"{LABELS[classIDs[i]]}: {confidences[i]:.4f}"
            cv2.putText(frame, text, (x, y - 5), cv2.FONT_HERSHEY_SIMPLEX, 0.5, color, 2)

    if writer is None:
        fourcc = cv2.VideoWriter_fourcc(*"MJPG")
        writer = cv2.VideoWriter(args["output"], fourcc, 30, (W, H), True)
        print("[INFO] VideoWriter initialized")

    writer.write(frame)

# Release pointers
print("[INFO] Cleaning up...")
writer.release()
vs.release()
# Out:
# Mounted at /content/drive
# [INFO] Loading YOLO from disk...
# [INFO] Video file opened successfully.
# [INFO] First frame read successfully.
# [INFO] Frame dimensions: 1280x720
# [INFO] 812 total frames in video
# [INFO] Processing frame 1
# [INFO] VideoWriter initialized
# [INFO] Processing frame 2
# [INFO] Processing frame 3
# [INFO] Processing frame 4
# [INFO] Processing frame 5
# [INFO] Processing frame 6
# [INFO] Processing frame 7
# [INFO] Processing frame 8
# [INFO] Processing frame 9
# [INFO] Processing frame 10
# [INFO] Processing frame 11
# [INFO] Processing frame 12
# [INFO] Processing frame 13
# [INFO] Processing frame 14
# [INFO] Processing frame 15
# [INFO] Processing frame 16
# [INFO] Processing frame 17
# [INFO] Processing frame 18
# [INFO] Processing frame 19
# [INFO] Processing frame 20
# [INFO] Processing frame 21
# [INFO] Processing frame 22
# [INFO] Processing frame 23
# [INFO] Processing frame 24
# [INFO] Processing frame 25
# [INFO] Processing frame 26
# [INFO] Processing frame 27
# [INFO] Processing frame 28
# [INFO] Processing frame 29
# [INFO] Processing frame 30
# [INFO] Processing frame 31
# [INFO] Processing frame 32
# [INFO] Processing frame 33
# [INFO] Processing frame 34
# [INFO] Processing frame 35
# [INFO] Processing frame 36
# [INFO] Processing frame 37
# [INFO] Processing frame 38
# [INFO] Processing frame 39
# [INFO] Processing frame 40
# [INFO] Processing frame 41
# [INFO] Processing frame 42
# [INFO] Processing frame 43
# [INFO] Processing frame 44
# [INFO] Processing frame 45
# [INFO] Processing frame 46
# [INFO] Processing frame 47
# [INFO] Processing frame 48
# [INFO] Processing frame 49
# [INFO] Processing frame 50
# [INFO] Processing frame 51
# [INFO] Processing frame 52
# [INFO] Processing frame 53
# [INFO] Processing frame 54
# [INFO] Processing frame 55
# [INFO] Processing frame 56
# [INFO] Processing frame 57
# [INFO] Processing frame 58
# [INFO] Processing frame 59
# [INFO] Processing frame 60
# [INFO] Processing frame 61
# [INFO] Processing frame 62
# [INFO] Processing frame 63
# [INFO] Processing frame 64
# [INFO] Processing frame 65
# [INFO] Processing frame 66
# [INFO] Processing frame 67
# [INFO] Processing frame 68
# [INFO] Processing frame 69
# [INFO] Processing frame 70
# [INFO] Processing frame 71
# [INFO] Processing frame 72
# [INFO] Processing frame 73
# [INFO] Processing frame 74
# [INFO] Processing frame 75
# [INFO] Processing frame 76
# [INFO] Processing frame 77
# [INFO] Processing frame 78
# [INFO] Processing frame 79
# [INFO] Processing frame 80
# [INFO] Processing frame 81
# [INFO] Processing frame 82
# [INFO] Processing frame 83
# [INFO] Processing frame 84
# [INFO] Processing frame 85
# [INFO] Processing frame 86
# [INFO] Processing frame 87
# [INFO] Processing frame 88
# [INFO] Processing frame 89
# [INFO] Processing frame 90
# [INFO] Processing frame 91
# [INFO] Processing frame 92
# [INFO] Processing frame 93
# [INFO] Processing frame 94
# [INFO] Processing frame 95
# [INFO] Processing frame 96
# [INFO] Processing frame 97
# [INFO] Processing frame 98
# [INFO] Processing frame 99
# [INFO] Processing frame 100
# [INFO] Processing frame 101
# [INFO] Processing frame 102
# [INFO] Processing frame 103
# [INFO] Processing frame 104
# [INFO] Processing frame 105
# [INFO] Processing frame 106
# [INFO] Processing frame 107
# [INFO] Processing frame 108
# [INFO] Processing frame 109
# [INFO] Processing frame 110
# [INFO] Processing frame 111
# [INFO] Processing frame 112
# [INFO] Processing frame 113
# [INFO] Processing frame 114
# [INFO] Processing frame 115
# [INFO] Processing frame 116
# [INFO] Processing frame 117
# [INFO] Processing frame 118
# [INFO] Processing frame 119
# [INFO] Processing frame 120
# [INFO] Processing frame 121
# [INFO] Processing frame 122
# [INFO] Processing frame 123
# [INFO] Processing frame 124
# [INFO] Processing frame 125
# [INFO] Processing frame 126
# [INFO] Processing frame 127
# [INFO] Processing frame 128
# [INFO] Processing frame 129
# [INFO] Processing frame 130
# [INFO] Processing frame 131
# [INFO] Processing frame 132
# [INFO] Processing frame 133
# [INFO] Processing frame 134
# [INFO] Processing frame 135
# [INFO] Processing frame 136
# [INFO] Processing frame 137
# [INFO] Processing frame 138
# [INFO] Processing frame 139
# [INFO] Processing frame 140
# [INFO] Processing frame 141
# [INFO] Processing frame 142
# [INFO] Processing frame 143
# [INFO] Processing frame 144
# [INFO] Processing frame 145
# [INFO] Processing frame 146
# [INFO] Processing frame 147
# [INFO] Processing frame 148
# [INFO] Processing frame 149
# [INFO] Processing frame 150
# [INFO] Processing frame 151
# [INFO] Processing frame 152
# [INFO] Processing frame 153
# [INFO] Processing frame 154
# [INFO] Processing frame 155
# [INFO] Processing frame 156
# [INFO] Processing frame 157
# [INFO] Processing frame 158
# [INFO] Processing frame 159
# [INFO] Processing frame 160
# [INFO] Processing frame 161
# [INFO] Processing frame 162
# [INFO] Processing frame 163
# [INFO] Processing frame 164
# [INFO] Processing frame 165
# [INFO] Processing frame 166
# [INFO] Processing frame 167
# [INFO] Processing frame 168
# [INFO] Processing frame 169
# [INFO] Processing frame 170
# [INFO] Processing frame 171
# [INFO] Processing frame 172
# [INFO] Processing frame 173
# [INFO] Processing frame 174
# [INFO] Processing frame 175
# [INFO] Processing frame 176
# [INFO] Processing frame 177
# [INFO] Processing frame 178
# [INFO] Processing frame 179
# [INFO] Processing frame 180
# [INFO] Processing frame 181
# [INFO] Processing frame 182
# [INFO] Processing frame 183
# [INFO] Processing frame 184
# [INFO] Processing frame 185
# [INFO] Processing frame 186
# [INFO] Processing frame 187
# [INFO] Processing frame 188
# [INFO] Processing frame 189
# [INFO] Processing frame 190
# [INFO] Processing frame 191
# [INFO] Processing frame 192
# [INFO] Processing frame 193
# [INFO] Processing frame 194
# [INFO] Processing frame 195
# [INFO] Processing frame 196
# [INFO] Processing frame 197
# [INFO] Processing frame 198
# [INFO] Processing frame 199
# [INFO] Processing frame 200
# [INFO] Processing frame 201
# [INFO] Processing frame 202
# [INFO] Processing frame 203
# [INFO] Processing frame 204
# [INFO] Processing frame 205
# [INFO] Processing frame 206
# [INFO] Processing frame 207
# [INFO] Processing frame 208
# [INFO] Processing frame 209
# [INFO] Processing frame 210
# [INFO] Processing frame 211
# [INFO] Processing frame 212
# [INFO] Processing frame 213
# [INFO] Processing frame 214
# [INFO] Processing frame 215
# [INFO] Processing frame 216
# [INFO] Processing frame 217
# [INFO] Processing frame 218
# [INFO] Processing frame 219
# [INFO] Processing frame 220
# [INFO] Processing frame 221
# [INFO] Processing frame 222
# [INFO] Processing frame 223
# [INFO] Processing frame 224
# [INFO] Processing frame 225
# [INFO] Processing frame 226
# [INFO] Processing frame 227
# [INFO] Processing frame 228
# [INFO] Processing frame 229
# [INFO] Processing frame 230
# [INFO] Processing frame 231
# [INFO] Processing frame 232
# [INFO] Processing frame 233
# [INFO] Processing frame 234
# [INFO] Processing frame 235
# [INFO] Processing frame 236
# [INFO] Processing frame 237
# [INFO] Processing frame 238
# [INFO] Processing frame 239
# [INFO] Processing frame 240
# [INFO] Processing frame 241
# [INFO] Processing frame 242
# [INFO] Processing frame 243
# [INFO] Processing frame 244
# [INFO] Processing frame 245
# [INFO] Processing frame 246
# [INFO] Processing frame 247
# [INFO] Processing frame 248
# [INFO] Processing frame 249
# [INFO] Processing frame 250
# [INFO] Processing frame 251
# [INFO] Processing frame 252
# [INFO] Processing frame 253
# [INFO] Processing frame 254
# [INFO] Processing frame 255
# [INFO] Processing frame 256
# [INFO] Processing frame 257
# [INFO] Processing frame 258
# [INFO] Processing frame 259
# [INFO] Processing frame 260
# [INFO] Processing frame 261
# [INFO] Processing frame 262
# [INFO] Processing frame 263
# [INFO] Processing frame 264
# [INFO] Processing frame 265
# [INFO] Processing frame 266
# [INFO] Processing frame 267
# [INFO] Processing frame 268
# [INFO] Processing frame 269
# [INFO] Processing frame 270
# [INFO] Processing frame 271
# [INFO] Processing frame 272
# [INFO] Processing frame 273
# [INFO] Processing frame 274
# [INFO] Processing frame 275
# [INFO] Processing frame 276
# [INFO] Processing frame 277
# [INFO] Processing frame 278
# [INFO] Processing frame 279
# [INFO] Processing frame 280
# [INFO] Processing frame 281
# [INFO] Processing frame 282
# [INFO] Processing frame 283
# [INFO] Processing frame 284
# [INFO] Processing frame 285
# [INFO] Processing frame 286
# [INFO] Processing frame 287
# [INFO] Processing frame 288
# [INFO] Processing frame 289
# [INFO] Processing frame 290
# [INFO] Processing frame 291
# [INFO] Processing frame 292
# [INFO] Processing frame 293
# [INFO] Processing frame 294
# [INFO] Processing frame 295
# [INFO] Processing frame 296
# [INFO] Processing frame 297
# [INFO] Processing frame 298
# [INFO] Processing frame 299
# [INFO] Processing frame 300
# [INFO] Processing frame 301
# [INFO] Processing frame 302
# [INFO] Processing frame 303
# [INFO] Processing frame 304
# [INFO] Processing frame 305
# [INFO] Processing frame 306
# [INFO] Processing frame 307
# [INFO] Processing frame 308
# [INFO] Processing frame 309
# [INFO] Processing frame 310
# [INFO] Processing frame 311
# [INFO] Processing frame 312
# [INFO] Processing frame 313
# [INFO] Processing frame 314
# [INFO] Processing frame 315
# [INFO] Processing frame 316
# [INFO] Processing frame 317
# [INFO] Processing frame 318
# [INFO] Processing frame 319
# [INFO] Processing frame 320
# [INFO] Processing frame 321
# [INFO] Processing frame 322
# [INFO] Processing frame 323
# [INFO] Processing frame 324
# [INFO] Processing frame 325
# [INFO] Processing frame 326
# [INFO] Processing frame 327
# [INFO] Processing frame 328
# [INFO] Processing frame 329
# [INFO] Processing frame 330
# [INFO] Processing frame 331
# [INFO] Processing frame 332
# [INFO] Processing frame 333
# [INFO] Processing frame 334
# [INFO] Processing frame 335
# [INFO] Processing frame 336
# [INFO] Processing frame 337
# [INFO] Processing frame 338
# [INFO] Processing frame 339
# [INFO] Processing frame 340
# [INFO] Processing frame 341
# [INFO] Processing frame 342
# [INFO] Processing frame 343
# [INFO] Processing frame 344
# [INFO] Processing frame 345
# [INFO] Processing frame 346
# [INFO] Processing frame 347
# [INFO] Processing frame 348
# [INFO] Processing frame 349
# [INFO] Processing frame 350
# [INFO] Processing frame 351
# [INFO] Processing frame 352
# [INFO] Processing frame 353
# [INFO] Processing frame 354
# [INFO] Processing frame 355
# [INFO] Processing frame 356
# [INFO] Processing frame 357
# [INFO] Processing frame 358
# [INFO] Processing frame 359
# [INFO] Processing frame 360
# [INFO] Processing frame 361
# [INFO] Processing frame 362
# [INFO] Processing frame 363
# [INFO] Processing frame 364
# [INFO] Processing frame 365
# [INFO] Processing frame 366
# [INFO] Processing frame 367
# [INFO] Processing frame 368
# [INFO] Processing frame 369
# [INFO] Processing frame 370
# [INFO] Processing frame 371
# [INFO] Processing frame 372
# [INFO] Processing frame 373
# [INFO] Processing frame 374
# [INFO] Processing frame 375
# [INFO] Processing frame 376
# [INFO] Processing frame 377
# [INFO] Processing frame 378
# [INFO] Processing frame 379
# [INFO] Processing frame 380
# [INFO] Processing frame 381
# [INFO] Processing frame 382
# [INFO] Processing frame 383
# [INFO] Processing frame 384
# [INFO] Processing frame 385
# [INFO] Processing frame 386
# [INFO] Processing frame 387
# [INFO] Processing frame 388
# [INFO] Processing frame 389
# [INFO] Processing frame 390
# [INFO] Processing frame 391
# [INFO] Processing frame 392
# [INFO] Processing frame 393
# [INFO] Processing frame 394
# [INFO] Processing frame 395
# [INFO] Processing frame 396
# [INFO] Processing frame 397
# [INFO] Processing frame 398
# [INFO] Processing frame 399
# [INFO] Processing frame 400
# [INFO] Processing frame 401
# [INFO] Processing frame 402
# [INFO] Processing frame 403
# [INFO] Processing frame 404
# [INFO] Processing frame 405
# [INFO] Processing frame 406
# [INFO] Processing frame 407
# [INFO] Processing frame 408
# [INFO] Processing frame 409
# [INFO] Processing frame 410
# [INFO] Processing frame 411
# [INFO] Processing frame 412
# [INFO] Processing frame 413
# [INFO] Processing frame 414
# [INFO] Processing frame 415
# [INFO] Processing frame 416
# [INFO] Processing frame 417
# [INFO] Processing frame 418
# [INFO] Processing frame 419
# [INFO] Processing frame 420
# [INFO] Processing frame 421
# [INFO] Processing frame 422
# [INFO] Processing frame 423
# [INFO] Processing frame 424
# [INFO] Processing frame 425
# [INFO] Processing frame 426
# [INFO] Processing frame 427
# [INFO] Processing frame 428
# [INFO] Processing frame 429
# [INFO] Processing frame 430
# [INFO] Processing frame 431
# [INFO] Processing frame 432
# [INFO] Processing frame 433
# [INFO] Processing frame 434
# [INFO] Processing frame 435
# [INFO] Processing frame 436
# [INFO] Processing frame 437
# [INFO] Processing frame 438
# [INFO] Processing frame 439
# [INFO] Processing frame 440
# [INFO] Processing frame 441
# [INFO] Processing frame 442
# [INFO] Processing frame 443
# [INFO] Processing frame 444
# [INFO] Processing frame 445
# [INFO] Processing frame 446
# [INFO] Processing frame 447
# [INFO] Processing frame 448
# [INFO] Processing frame 449
# [INFO] Processing frame 450
# [INFO] Processing frame 451
# [INFO] Processing frame 452
# [INFO] Processing frame 453
# [INFO] Processing frame 454
# [INFO] Processing frame 455
# [INFO] Processing frame 456
# [INFO] Processing frame 457
# [INFO] Processing frame 458
# [INFO] Processing frame 459
# [INFO] Processing frame 460
# [INFO] Processing frame 461
# [INFO] Processing frame 462
# [INFO] Processing frame 463
# [INFO] Processing frame 464
# [INFO] Processing frame 465
# [INFO] Processing frame 466
# [INFO] Processing frame 467
# [INFO] Processing frame 468
# [INFO] Processing frame 469
# [INFO] Processing frame 470
# [INFO] Processing frame 471
# [INFO] Processing frame 472
# [INFO] Processing frame 473
# [INFO] Processing frame 474
# [INFO] Processing frame 475
# [INFO] Processing frame 476
# [INFO] Processing frame 477
# [INFO] Processing frame 478
# [INFO] Processing frame 479
# [INFO] Processing frame 480
# [INFO] Processing frame 481
# [INFO] Processing frame 482
# [INFO] Processing frame 483
# [INFO] Processing frame 484
# [INFO] Processing frame 485
# [INFO] Processing frame 486
# [INFO] Processing frame 487
# [INFO] Processing frame 488
# [INFO] Processing frame 489
# [INFO] Processing frame 490
# [INFO] Processing frame 491
# [INFO] Processing frame 492
# [INFO] Processing frame 493
# [INFO] Processing frame 494
# [INFO] Processing frame 495
# [INFO] Processing frame 496
# [INFO] Processing frame 497
# [INFO] Processing frame 498
# [INFO] Processing frame 499
# [INFO] Processing frame 500
# [INFO] Processing frame 501
# [INFO] Processing frame 502
# [INFO] Processing frame 503
# [INFO] Processing frame 504
# [INFO] Processing frame 505
# [INFO] Processing frame 506
# [INFO] Processing frame 507
# [INFO] Processing frame 508
# [INFO] Processing frame 509
# [INFO] Processing frame 510
# [INFO] Processing frame 511
# [INFO] Processing frame 512
# [INFO] Processing frame 513
# [INFO] Processing frame 514
# [INFO] Processing frame 515
# [INFO] Processing frame 516
# [INFO] Processing frame 517
# [INFO] Processing frame 518
# [INFO] Processing frame 519
# [INFO] Processing frame 520
# [INFO] Processing frame 521
# [INFO] Processing frame 522
# [INFO] Processing frame 523
# [INFO] Processing frame 524
# [INFO] Processing frame 525
# [INFO] Processing frame 526
# [INFO] Processing frame 527
# [INFO] Processing frame 528
# [INFO] Processing frame 529
# [INFO] Processing frame 530
# [INFO] Processing frame 531
# [INFO] Processing frame 532
# [INFO] Processing frame 533
# [INFO] Processing frame 534
# [INFO] Processing frame 535
# [INFO] Processing frame 536
# [INFO] Processing frame 537
# [INFO] Processing frame 538
# [INFO] Processing frame 539
# [INFO] Processing frame 540
# [INFO] Processing frame 541
# [INFO] Processing frame 542
# [INFO] Processing frame 543
# [INFO] Processing frame 544
# [INFO] Processing frame 545
# [INFO] Processing frame 546
# [INFO] Processing frame 547
# [INFO] Processing frame 548
# [INFO] Processing frame 549
# [INFO] Processing frame 550
# [INFO] Processing frame 551
# [INFO] Processing frame 552
# [INFO] Processing frame 553
# [INFO] Processing frame 554
# [INFO] Processing frame 555
# [INFO] Processing frame 556
# [INFO] Processing frame 557
# [INFO] Processing frame 558
# [INFO] Processing frame 559
# [INFO] Processing frame 560
# [INFO] Processing frame 561
# [INFO] Processing frame 562
# [INFO] Processing frame 563
# [INFO] Processing frame 564
# [INFO] Processing frame 565
# [INFO] Processing frame 566
# [INFO] Processing frame 567
# [INFO] Processing frame 568
# [INFO] Processing frame 569
# [INFO] Processing frame 570
# [INFO] Processing frame 571
# [INFO] Processing frame 572
# [INFO] Processing frame 573
# [INFO] Processing frame 574
# [INFO] Processing frame 575
# [INFO] Processing frame 576
# [INFO] Processing frame 577
# [INFO] Processing frame 578
# [INFO] Processing frame 579
# [INFO] Processing frame 580
# [INFO] Processing frame 581
# [INFO] Processing frame 582
# [INFO] Processing frame 583
# [INFO] Processing frame 584
# [INFO] Processing frame 585
# [INFO] Processing frame 586
# [INFO] Processing frame 587
# [INFO] Processing frame 588
# [INFO] Processing frame 589
# [INFO] Processing frame 590
# [INFO] Processing frame 591
# [INFO] Processing frame 592
# [INFO] Processing frame 593
# [INFO] Processing frame 594
# [INFO] Processing frame 595
# [INFO] Processing frame 596
# [INFO] Processing frame 597
# [INFO] Processing frame 598
# [INFO] Processing frame 599
# [INFO] Processing frame 600
# [INFO] Processing frame 601
# [INFO] Processing frame 602
# [INFO] Processing frame 603
# [INFO] Processing frame 604
# [INFO] Processing frame 605
# [INFO] Processing frame 606
# [INFO] Processing frame 607
# [INFO] Processing frame 608
# [INFO] Processing frame 609
# [INFO] Processing frame 610
# [INFO] Processing frame 611
# [INFO] Processing frame 612
# [INFO] Processing frame 613
# [INFO] Processing frame 614
# [INFO] Processing frame 615
# [INFO] Processing frame 616
# [INFO] Processing frame 617
# [INFO] Processing frame 618
# [INFO] Processing frame 619
# [INFO] Processing frame 620
# [INFO] Processing frame 621
# [INFO] Processing frame 622
# [INFO] Processing frame 623
# [INFO] Processing frame 624
# [INFO] Processing frame 625
# [INFO] Processing frame 626
# [INFO] Processing frame 627
# [INFO] Processing frame 628
# [INFO] Processing frame 629
# [INFO] Processing frame 630
# [INFO] Processing frame 631
# [INFO] Processing frame 632
# [INFO] Processing frame 633
# [INFO] Processing frame 634
# [INFO] Processing frame 635
# [INFO] Processing frame 636
# [INFO] Processing frame 637
# [INFO] Processing frame 638
# [INFO] Processing frame 639
# [INFO] Processing frame 640
# [INFO] Processing frame 641
# [INFO] Processing frame 642
# [INFO] Processing frame 643
# [INFO] Processing frame 644
# [INFO] Processing frame 645
# [INFO] Processing frame 646
# [INFO] Processing frame 647
# [INFO] Processing frame 648
# [INFO] Processing frame 649
# [INFO] Processing frame 650
# [INFO] Processing frame 651
# [INFO] Processing frame 652
# [INFO] Processing frame 653
# [INFO] Processing frame 654
# [INFO] Processing frame 655
# [INFO] Processing frame 656
# [INFO] Processing frame 657
# [INFO] Processing frame 658
# [INFO] Processing frame 659
# [INFO] Processing frame 660
# [INFO] Processing frame 661
# [INFO] Processing frame 662
# [INFO] Processing frame 663
# [INFO] Processing frame 664
# [INFO] Processing frame 665
# [INFO] Processing frame 666
# [INFO] Processing frame 667
# [INFO] Processing frame 668
# [INFO] Processing frame 669
# [INFO] Processing frame 670
# [INFO] Processing frame 671
# [INFO] Processing frame 672
# [INFO] Processing frame 673
# [INFO] Processing frame 674
# [INFO] Processing frame 675
# [INFO] Processing frame 676
# [INFO] Processing frame 677
# [INFO] Processing frame 678
# [INFO] Processing frame 679
# [INFO] Processing frame 680
# [INFO] Processing frame 681
# [INFO] Processing frame 682
# [INFO] Processing frame 683
# [INFO] Processing frame 684
# [INFO] Processing frame 685
# [INFO] Processing frame 686
# [INFO] Processing frame 687
# [INFO] Processing frame 688
# [INFO] Processing frame 689
# [INFO] Processing frame 690
# [INFO] Processing frame 691
# [INFO] Processing frame 692
# [INFO] Processing frame 693
# [INFO] Processing frame 694
# [INFO] Processing frame 695
# [INFO] Processing frame 696
# [INFO] Processing frame 697
# [INFO] Processing frame 698
# [INFO] Processing frame 699
# [INFO] Processing frame 700
# [INFO] Processing frame 701
# [INFO] Processing frame 702
# [INFO] Processing frame 703
# [INFO] Processing frame 704
# [INFO] Processing frame 705
# [INFO] Processing frame 706
# [INFO] Processing frame 707
# [INFO] Processing frame 708
# [INFO] Processing frame 709
# [INFO] Processing frame 710
# [INFO] Processing frame 711
# [INFO] Processing frame 712
# [INFO] Processing frame 713
# [INFO] Processing frame 714
# [INFO] Processing frame 715
# [INFO] Processing frame 716
# [INFO] Processing frame 717
# [INFO] Processing frame 718
# [INFO] Processing frame 719
# [INFO] Processing frame 720
# [INFO] Processing frame 721
# [INFO] Processing frame 722
# [INFO] Processing frame 723
# [INFO] Processing frame 724
# [INFO] Processing frame 725
# [INFO] Processing frame 726
# [INFO] Processing frame 727
# [INFO] Processing frame 728
# [INFO] Processing frame 729
# [INFO] Processing frame 730
# [INFO] Processing frame 731
# [INFO] Processing frame 732
# [INFO] Processing frame 733
# [INFO] Processing frame 734
# [INFO] Processing frame 735
# [INFO] Processing frame 736
# [INFO] Processing frame 737
# [INFO] Processing frame 738
# [INFO] Processing frame 739
# [INFO] Processing frame 740
# [INFO] Processing frame 741
# [INFO] Processing frame 742
# [INFO] Processing frame 743
# [INFO] Processing frame 744
# [INFO] Processing frame 745
# [INFO] Processing frame 746
# [INFO] Processing frame 747
# [INFO] Processing frame 748
# [INFO] Processing frame 749
# [INFO] Processing frame 750
# [INFO] Processing frame 751
# [INFO] Processing frame 752
# [INFO] Processing frame 753
# [INFO] Processing frame 754
# [INFO] Processing frame 755
# [INFO] Processing frame 756
# [INFO] Processing frame 757
# [INFO] Processing frame 758
# [INFO] Processing frame 759
# [INFO] Processing frame 760
# [INFO] Processing frame 761
# [INFO] Processing frame 762
# [INFO] Processing frame 763
# [INFO] Processing frame 764
# [INFO] Processing frame 765
# [INFO] Processing frame 766
# [INFO] Processing frame 767
# [INFO] Processing frame 768
# [INFO] Processing frame 769
# [INFO] Processing frame 770
# [INFO] Processing frame 771
# [INFO] Processing frame 772
# [INFO] Processing frame 773
# [INFO] Processing frame 774
# [INFO] Processing frame 775
# [INFO] Processing frame 776
# [INFO] Processing frame 777
# [INFO] Processing frame 778
# [INFO] Processing frame 779
# [INFO] Processing frame 780
# [INFO] Processing frame 781
# [INFO] Processing frame 782
# [INFO] Processing frame 783
# [INFO] Processing frame 784
# [INFO] Processing frame 785
# [INFO] Processing frame 786
# [INFO] Processing frame 787
# [INFO] Processing frame 788
# [INFO] Processing frame 789
# [INFO] Processing frame 790
# [INFO] Processing frame 791
# [INFO] Processing frame 792
# [INFO] Processing frame 793
# [INFO] Processing frame 794
# [INFO] Processing frame 795
# [INFO] Processing frame 796
# [INFO] Processing frame 797
# [INFO] Processing frame 798
# [INFO] Processing frame 799
# [INFO] Processing frame 800
# [INFO] Processing frame 801
# [INFO] Processing frame 802
# [INFO] Processing frame 803
# [INFO] Processing frame 804
# [INFO] Processing frame 805
# [INFO] Processing frame 806
# [INFO] Processing frame 807
# [INFO] Processing frame 808
# [INFO] Processing frame 809
# [INFO] Processing frame 810
# [INFO] Processing frame 811
# [INFO] Cleaning up...
